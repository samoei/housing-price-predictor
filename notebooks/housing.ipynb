# %%
import sys
assert sys.version_info >= (3, 7)

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %% [markdown]
# # Get the Data

# %%
from pathlib import Path
import pandas as pd
import tarfile 
import urllib.request


def load_housing_data():
    tarball_path = Path("../data/raw/housing.tgz")
    if not tarball_path.is_file():
        Path("../data/raw/").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="../data/raw")
    return pd.read_csv(Path("../data/raw/housing/housing.csv"))

housing = load_housing_data()

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
IMAGES_PATH = Path("../reports/figures/housing")
IMAGES_PATH.mkdir(parents=True, exist_ok=True)


def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import matplotlib.pyplot as plt
# extra code – the next 5 lines define the default font sizes
plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

housing.hist(bins=50, figsize=(12, 8))
save_fig("attribute_histogram_plots")  # extra code
plt.show()

# %% [markdown]
# # Create a Test Set

# %% [markdown]
# ## Simple split using random sampling
# This is a basic split that splits data based on the split ratio for example 20% of the data is going to be set aside for testing.

# %%
import numpy as np 

def shuffle_and_split_data(data, split_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * split_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = shuffle_and_split_data(housing, 0.2)

# %%
len(train_set)
# Out:
# 16512

# %%
len(test_set)
# Out:
# 4128

# %%
train_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8231     -119.76     36.76                23.0       3800.0          1003.0
# 13741    -121.47     39.49                17.0       1554.0           242.0
# 12008    -117.25     34.06                18.0       5009.0          1108.0
# 2586     -118.15     33.79                 5.0       3700.0           993.0
# 4064     -118.42     34.26                37.0       1789.0           424.0
#
#        population  households  median_income  median_house_value  \
# 8231       3786.0       917.0         1.4766             50600.0
# 13741       553.0       230.0         3.2174             91800.0
# 12008      2948.0       963.0         3.0042            106500.0
# 2586       1657.0       848.0         3.7826            196300.0
# 4064       2279.0       411.0         3.9000            138600.0
#
#       ocean_proximity
# 8231           INLAND
# 13741          INLAND
# 12008          INLAND
# 2586       NEAR OCEAN
# ...

# %%
test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7080     -121.82     37.98                13.0       3995.0           605.0
# 2499     -117.02     32.74                12.0       3301.0           963.0
# 5805     -122.07     38.27                 8.0       6761.0          1234.0
# 3989     -118.49     34.25                28.0       4054.0           712.0
# 14768    -122.38     40.20                16.0       2722.0           511.0
#
#        population  households  median_income  median_house_value  \
# 7080       1969.0       607.0         5.0164            165200.0
# 2499       2000.0       879.0         1.8594            119200.0
# 5805       3237.0      1177.0         4.3586            173400.0
# 3989       2164.0       746.0         5.0000            258000.0
# 14768      1366.0       495.0         2.8447             87700.0
#
#       ocean_proximity
# 7080           INLAND
# 2499       NEAR OCEAN
# 5805           INLAND
# 3989        <1H OCEAN
# ...

# %%
# for consistency
np.random.seed(42)

# %% [markdown]
# The challenges of splitiing with the above methods is that it lacks consistency of separating between the test and the train splits every time data is reloaded.
#
# A common solution is to use an unique id on each row and based on it decide whether its going to be used for training or testing. For example using the unique ID you could compute a hash value which will be part of data. If the value of the hash is equal or leass than the 20% of the max hash then its separated and used for testing.

# %%
from zlib import crc32

def id_belongs_to_test_set(id, split_ratio):
    return crc32(np.int64(id)) < split_ratio * 2**32

# %%
def split_data_using_hash(data, split_ratio, id_col):
    ids = data[id_col]
    in_test_set = ids.apply(lambda id_: id_belongs_to_test_set(id_, split_ratio))
    return data.loc[~in_test_set], data.loc[in_test_set]

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_with_ids = housing.reset_index()
housing_with_ids.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY

# %%
train_set, test_set = split_data_using_hash(housing_with_ids, 0.2, "index")
train_set.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
# 6      6    -122.25     37.84                52.0       2535.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
# 6           489.0      1094.0       514.0         3.6591            299200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
# 6        NEAR BAY

# %%
test_set.head()
# Out:
#     index  longitude  latitude  housing_median_age  total_rooms  \
# 2       2    -122.24     37.85                52.0       1467.0
# 5       5    -122.25     37.85                52.0        919.0
# 12     12    -122.26     37.85                52.0       2491.0
# 16     16    -122.27     37.85                52.0       1966.0
# 23     23    -122.27     37.84                52.0       1688.0
#
#     total_bedrooms  population  households  median_income  median_house_value  \
# 2            190.0       496.0       177.0         7.2574            352100.0
# 5            213.0       413.0       193.0         4.0368            269700.0
# 12           474.0      1098.0       468.0         3.0750            213500.0
# 16           347.0       793.0       331.0         2.7750            152500.0
# 23           337.0       853.0       325.0         2.1806             99700.0
#
#    ocean_proximity
# 2         NEAR BAY
# 5         NEAR BAY
# 12        NEAR BAY
# 16        NEAR BAY
# ...

# %% [markdown]
# The challenge with using a new ID is that whenever you have new data added to the index yopu have to ensure its appended to thew end and no prior index (AKA IDs) are deleted. This is taxing and unstable.
#
# An even better solution is to use the most stab features (columns) of your data.

# %%
housing_with_ids["id"] = housing["longitude"] * 1000 + housing["latitude"]
train_set, test_set = split_data_using_hash(housing_with_ids, 0.2, "id")

# %%
housing_with_ids.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity         id
# 0        NEAR BAY -122192.12
# 1        NEAR BAY -122182.14
# 2        NEAR BAY -122202.15
# ...

# %%
train_set.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity         id
# 0        NEAR BAY -122192.12
# 1        NEAR BAY -122182.14
# 2        NEAR BAY -122202.15
# ...

# %%
test_set.head()
# Out:
#     index  longitude  latitude  housing_median_age  total_rooms  \
# 59     59    -122.29     37.82                 2.0        158.0
# 60     60    -122.29     37.83                52.0       1121.0
# 61     61    -122.29     37.82                49.0        135.0
# 62     62    -122.29     37.81                50.0        760.0
# 67     67    -122.29     37.80                52.0       1027.0
#
#     total_bedrooms  population  households  median_income  median_house_value  \
# 59            43.0        94.0        57.0         2.5625             60000.0
# 60           211.0       554.0       187.0         3.3929             75700.0
# 61            29.0        86.0        23.0         6.1183             75000.0
# 62           190.0       377.0       122.0         0.9011             86100.0
# 67           244.0       492.0       147.0         2.6094             81300.0
#
#    ocean_proximity         id
# 59        NEAR BAY -122252.18
# 60        NEAR BAY -122252.17
# ...

# %%
len(train_set)
# Out:
# 16322

# %%
len(test_set)
# Out:
# 4318

# %% [markdown]
# Scikit-Learn comes with a simple `train_test_split` function that basically does the same thing we did earlier.

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
train_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.22     32.75                34.0       6001.0          1111.0
# 8267     -117.03     32.69                10.0        901.0           163.0
# 17445    -122.27     37.74                28.0       6909.0          1554.0
# 14265    -121.82     37.25                25.0       4021.0           634.0
# 2271     -115.98     33.32                 8.0        240.0            46.0
#
#        population  households  median_income  median_house_value  \
# 14196      2654.0      1072.0         4.5878            291000.0
# 8267        698.0       167.0         4.6648            156100.0
# 17445      2974.0      1484.0         3.6875            353900.0
# 14265      2178.0       650.0         5.1663            241200.0
# 2271         63.0        24.0         1.4688             53800.0
#
#       ocean_proximity
# 14196      NEAR OCEAN
# 8267       NEAR OCEAN
# 17445        NEAR BAY
# 14265       <1H OCEAN
# ...

# %%
test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -122.38     40.67                10.0       2281.0           444.0
# 3024     -118.37     33.83                35.0       1207.0           207.0
# 15663    -117.24     32.72                39.0       3089.0           431.0
# 20484    -118.44     34.05                18.0       4780.0          1192.0
# 9814     -118.44     34.18                33.0       2127.0           414.0
#
#        population  households  median_income  median_house_value  \
# 20046      1274.0       438.0         2.2120             65600.0
# 3024        601.0       213.0         4.7308            353400.0
# 15663      1175.0       432.0         7.5925            466700.0
# 20484      1886.0      1036.0         4.4674            500001.0
# 9814       1056.0       391.0         4.3750            286100.0
#
#       ocean_proximity
# 20046          INLAND
# 3024        <1H OCEAN
# 15663      NEAR OCEAN
# 20484       <1H OCEAN
# ...

# %% [markdown]
# ## Stratified Sampling

# %% [markdown]
# We know median income from the data is going to affect the housing prices in the area, we need to ensure we select the right represemtation of this in the split between train and test sets
#
# We will categories income into 5 buckets and see how many households are in each bucket.

# %%
housing["income_cat"] = pd.cut(housing["median_income"], bins=[0., 1.5, 3., 4.5, 6., np.inf], labels=[1,2,3,4,5])

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#   income_cat
# 0          5
# 1          5
# 2          5
# ...

# %%
housing["income_cat"].value_counts().sort_index()
# Out:
# 1     822
# 2    6581
# 3    7236
# 4    3639
# 5    2362
# Name: income_cat, dtype: int64

# %%
housing["income_cat"].value_counts().sort_index().plot.bar(rot=0, grid=True)
plt.xlabel("Income category")
plt.ylabel("Number of districts")
save_fig("housing_income_cat_bar_plot")
plt.show()

# %% [markdown]
# Generate 10 different stratified splits of the same dataset

# %%
from sklearn.model_selection import StratifiedShuffleSplit

splitter = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=42)
strat_splits = []

for train_index, test_index in splitter.split(housing, housing["income_cat"]):
    strat_train_set_n = housing.iloc[train_index]
    strat_test_set_n = housing.iloc[test_index]
    strat_splits.append([strat_train_set_n, strat_test_set_n])

# %%
strat_train_set, strat_test_set =  strat_splits[0]

# %%
strat_train_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13096    -122.42     37.80                52.0       3321.0          1115.0
# 14973    -118.38     34.14                40.0       1965.0           354.0
# 3785     -121.98     38.36                33.0       1083.0           217.0
# 14689    -117.11     33.75                17.0       4174.0           851.0
# 20507    -118.15     33.77                36.0       4366.0          1211.0
#
#        population  households  median_income  median_house_value  \
# 13096      1576.0      1034.0         2.0987            458300.0
# 14973       666.0       357.0         6.0876            483800.0
# 3785        562.0       203.0         2.4330            101700.0
# 14689      1845.0       780.0         2.2618             96100.0
# 20507      1912.0      1172.0         3.5292            361800.0
#
#       ocean_proximity income_cat
# 13096        NEAR BAY          2
# 14973       <1H OCEAN          5
# ...

# %%
strat_test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3905     -121.95     37.11                21.0       2387.0           357.0
# 16821    -118.01     33.89                36.0       1589.0           265.0
# 2900     -118.18     33.74                30.0       5915.0          1750.0
# 7193     -122.48     37.74                52.0       2166.0           423.0
# 13928    -122.39     37.78                 5.0       1405.0           515.0
#
#        population  households  median_income  median_house_value  \
# 3905        913.0       341.0         7.7360            397700.0
# 16821       804.0       272.0         4.6354            202900.0
# 2900       2136.0      1503.0         4.0968            310000.0
# 7193       1072.0       370.0         4.1310            314300.0
# 13928       725.0       392.0         3.6037            187500.0
#
#       ocean_proximity income_cat
# 3905        <1H OCEAN          5
# 16821       <1H OCEAN          4
# ...

# %% [markdown]
# Income category proportions in the test set

# %%
strat_test_set["income_cat"].value_counts()/len(strat_test_set)*100
# Out:
# 3    35.053295
# 2    31.879845
# 4    17.635659
# 5    11.434109
# 1     3.997093
# Name: income_cat, dtype: float64

# %% [markdown]
# since stratified sampling is fairly common, there’s a shorter way to get a single split using the `train_test_split()` function with the `stratify` argument

# %%
strat_train_set, strat_test_set = train_test_split(housing, test_size=0.2, stratify=housing["income_cat"], random_state=42)

# %%
strat_test_set["income_cat"].value_counts()/len(strat_test_set)*100
# Out:
# 3    35.053295
# 2    31.879845
# 4    17.635659
# 5    11.434109
# 1     3.997093
# Name: income_cat, dtype: float64

# %% [markdown]
# Sampling bias comparison of stratified versus purely random sampling

# %%
def income_cat_proportions(data):
    return data["income_cat"].value_counts() / len(data)
    
    
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

compare_proportions = pd.DataFrame({
    "Overall %" : income_cat_proportions(housing),
    "Random %": income_cat_proportions(test_set),
    "Stratified %": income_cat_proportions(strat_test_set)
}).sort_index()

compare_proportions.index.name = "Income Category"

compare_proportions["Strat. Error %"] = (compare_proportions["Stratified %"] / compare_proportions["Overall %"] - 1)
compare_proportions["Rand. Error %"] = (compare_proportions["Random %"] / compare_proportions["Overall %"] - 1)

(compare_proportions * 100).round(2)
# Out:
#                  Overall %  Random %  Stratified %  Strat. Error %  \
# Income Category
# 1                     3.98      4.24          4.00            0.36
# 2                    31.88     30.74         31.88           -0.02
# 3                    35.06     34.52         35.05           -0.01
# 4                    17.63     18.41         17.64            0.03
# 5                    11.44     12.09         11.43           -0.08
#
#                  Rand. Error %
# Income Category
# 1                         6.45
# 2                        -3.59
# 3                        -1.53
# 4                         4.42
# 5                         5.63

# %% [markdown]
# Dropping `income_cat` column as we will no longer need it.

# %%
strat_test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3905     -121.95     37.11                21.0       2387.0           357.0
# 16821    -118.01     33.89                36.0       1589.0           265.0
# 2900     -118.18     33.74                30.0       5915.0          1750.0
# 7193     -122.48     37.74                52.0       2166.0           423.0
# 13928    -122.39     37.78                 5.0       1405.0           515.0
#
#        population  households  median_income  median_house_value  \
# 3905        913.0       341.0         7.7360            397700.0
# 16821       804.0       272.0         4.6354            202900.0
# 2900       2136.0      1503.0         4.0968            310000.0
# 7193       1072.0       370.0         4.1310            314300.0
# 13928       725.0       392.0         3.6037            187500.0
#
#       ocean_proximity income_cat
# 3905        <1H OCEAN          5
# 16821       <1H OCEAN          4
# ...

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop("income_cat", axis=1, inplace=True)

# %%
strat_test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3905     -121.95     37.11                21.0       2387.0           357.0
# 16821    -118.01     33.89                36.0       1589.0           265.0
# 2900     -118.18     33.74                30.0       5915.0          1750.0
# 7193     -122.48     37.74                52.0       2166.0           423.0
# 13928    -122.39     37.78                 5.0       1405.0           515.0
#
#        population  households  median_income  median_house_value  \
# 3905        913.0       341.0         7.7360            397700.0
# 16821       804.0       272.0         4.6354            202900.0
# 2900       2136.0      1503.0         4.0968            310000.0
# 7193       1072.0       370.0         4.1310            314300.0
# 13928       725.0       392.0         3.6037            187500.0
#
#       ocean_proximity
# 3905        <1H OCEAN
# 16821       <1H OCEAN
# 2900       NEAR OCEAN
# 7193       NEAR OCEAN
# ...

# %% [markdown]
# # Exploring and Visualizing the Data to Gain Insights

# %% [markdown]
# Since we are going to experiment with various transformations make a copy of the original data so we can revert to it afterwards

# %%
housing = strat_train_set.copy()

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13096    -122.42     37.80                52.0       3321.0          1115.0
# 14973    -118.38     34.14                40.0       1965.0           354.0
# 3785     -121.98     38.36                33.0       1083.0           217.0
# 14689    -117.11     33.75                17.0       4174.0           851.0
# 20507    -118.15     33.77                36.0       4366.0          1211.0
#
#        population  households  median_income  median_house_value  \
# 13096      1576.0      1034.0         2.0987            458300.0
# 14973       666.0       357.0         6.0876            483800.0
# 3785        562.0       203.0         2.4330            101700.0
# 14689      1845.0       780.0         2.2618             96100.0
# 20507      1912.0      1172.0         3.5292            361800.0
#
#       ocean_proximity
# 13096        NEAR BAY
# 14973       <1H OCEAN
# 3785           INLAND
# 14689          INLAND
# ...

# %% [markdown]
# ## Visualising Geographical data

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", grid=True)
save_fig("bad_visualization_plot")
plt.show()

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", grid=True, alpha=0.2)
save_fig("better_visualization_plot")
plt.show()
